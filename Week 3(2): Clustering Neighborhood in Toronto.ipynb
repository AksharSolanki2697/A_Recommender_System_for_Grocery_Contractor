# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

soup = BeautifulSoup(raw_wikipedia_page,'xml')

#print(soup.prettify())
#The prettify() method will turn a Beautiful Soup parse tree into a nicely formatted Unicode string, with a separate line for each HTML/XML tag and string

# %%
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []
for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 77

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(14)
# Out:
#              Borough                                      Neighbourhood  \
# 0   Downtown Toronto                          Harbourfront, Regent Park
# 1          Etobicoke                                       The Kingsway
# 2   Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Sou...
# 3         North York                     Bathurst Manor, Wilson Heights
# 4         North York                   Lawrence Heights, Lawrence Manor
# 5   Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 6         North York                    Northwood Park, York University
# 7        Scarborough                              Ionview, Kennedy Park
# 8               York                                             Weston
# 9       West Toronto                                 Runnymede, Swansea
# 10       Scarborough                                  Maryvale, Wexford
# 11        North York                                    Bayview Village
# 12       Scarborough                                             Woburn
# 13       Scarborough                                        Upper Rouge
#
#    Postcode
# 0       M5A
# 1       M8X
# 2       M5V
# 3       M3H
# 4       M6A
# 5       M5T
# 6       M3J
# 7       M1K
# 8       M9N
# 9       M6S
# 10      M1R
# 11      M2K
# 12      M1G
# 13      M1X

# %%
df = pd.read_csv('http://cocl.us/Geospatial_data')
df.columns = ['Postcode','Latitude','Longitude']

# %%
#df_toronto
#df

# %%
final_df = df_toronto.merge(df, how='left', on='Postcode')
final_df
# Out:
#              Borough                                      Neighbourhood  \
# 0   Downtown Toronto                          Harbourfront, Regent Park
# 1          Etobicoke                                       The Kingsway
# 2   Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Sou...
# 3         North York                     Bathurst Manor, Wilson Heights
# 4         North York                   Lawrence Heights, Lawrence Manor
# 5   Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 6         North York                    Northwood Park, York University
# 7        Scarborough                              Ionview, Kennedy Park
# 8               York                                             Weston
# 9       West Toronto                                 Runnymede, Swansea
# 10       Scarborough                                  Maryvale, Wexford
# 11        North York                                    Bayview Village
# 12       Scarborough                                             Woburn
# 13       Scarborough                                        Upper Rouge
# 14       Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 15        North York                                    Willowdale West
# 16        North York                                      Humber Summit
# 17      East Toronto                                          Riverdale
# 18         Etobicoke       Islington, Princess Gardens, West Deane Park
# 19  Downtown Toronto                                        Berczy Park
# 20        North York                                         Henry Farm
# 21         East York                                   Thorncliffe Park
# 22         Etobicoke                      Mimico NW, The Queensway West
# 23         East York                    Woodbine Gardens, Parkview Hill
# 24       Scarborough             Highland Creek, Rouge Hill, Port Union
# 25         East York                                            Leaside
# 26      West Toronto                           Little Portugal, Trinity
# 27       Scarborough                          Agincourt North, Milliken
# 28  Downtown Toronto                                           Rosedale
# 29       Scarborough                              Cliffcrest, Cliffside
# ..               ...                                                ...
# 47      West Toronto                             Parkdale, Roncesvalles
# 48  Downtown Toronto                                     Commerce Court
# 49        North York                            Newtonbrook, Willowdale
# 50         Etobicoke  Beaumond Heights, Jamestown, Mount Olive, Silv...
# 51         Etobicoke                             Alderwood, Long Branch
# 52       Scarborough                                Scarborough Village
# 53  Downtown Toronto                              University of Toronto
# 54  Downtown Toronto           Design Exchange, Toronto Dominion Centre
# 55        North York                                    Flemingdon Park
# 56        North York                                       Bedford Park
# 57      West Toronto                 Exhibition Place, Parkdale Village
# 58       Scarborough                    Clairlea, Golden Mile, Oakridge
# 59         Etobicoke                                   Islington Avenue
# 60         Etobicoke  Humber Bay, Mimico NE, Old Mill South, The Que...
# 61   Central Toronto                                         Moore Park
# 62         East York                                   Woodbine Heights
# 63         Etobicoke                                  Kingsview Village
# 64  Downtown Toronto                     Toronto Islands, Union Station
# 65         East York                                       East Toronto
# 66        North York                                   Emery, Humberlea
# 67       Scarborough                                     Rouge, Malvern
# 68  Downtown Toronto             First Canadian Place, Underground city
# 69  Downtown Toronto                               Church and Wellesley
# 70        North York                                     Downsview West
# 71      West Toronto                                 Dovercourt Village
# 72        North York                                         York Mills
# 73   Central Toronto                               The Annex, Yorkville
# 74  Downtown Toronto                        Cabbagetown, St. James Town
# 75   Central Toronto                   Deer Park, Rathnelly, South Hill
# 76      East Toronto                                       India Bazaar
#
#    Postcode   Latitude  Longitude
# 0       M5A  43.654260 -79.360636
# 1       M8X  43.653654 -79.506944
# 2       M5V  43.628947 -79.394420
# 3       M3H  43.754328 -79.442259
# 4       M6A  43.718518 -79.464763
# 5       M5T  43.653206 -79.400049
# 6       M3J  43.767980 -79.487262
# 7       M1K  43.727929 -79.262029
# 8       M9N  43.706876 -79.518188
# 9       M6S  43.651571 -79.484450
# 10      M1R  43.750072 -79.295849
# 11      M2K  43.786947 -79.385975
# 12      M1G  43.770992 -79.216917
# 13      M1X  43.836125 -79.205636
# 14      M1P  43.757410 -79.273304
# 15      M2R  43.782736 -79.442259
# 16      M9L  43.756303 -79.565963
# 17      M4K  43.679557 -79.352188
# 18      M9B  43.650943 -79.554724
# 19      M5E  43.644771 -79.373306
# 20      M2J  43.778517 -79.346556
# 21      M4H  43.705369 -79.349372
# 22      M8Z  43.628841 -79.520999
# 23      M4B  43.706397 -79.309937
# 24      M1C  43.784535 -79.160497
# 25      M4G  43.709060 -79.363452
# 26      M6J  43.647927 -79.419750
# 27      M1V  43.815252 -79.284577
# 28      M4W  43.679563 -79.377529
# 29      M1M  43.716316 -79.239476
# ..      ...        ...        ...
# 47      M6R  43.648960 -79.456325
# 48      M5L  43.648198 -79.379817
# 49      M2M  43.789053 -79.408493
# 50      M9V  43.739416 -79.588437
# 51      M8W  43.602414 -79.543484
# 52      M1J  43.744734 -79.239476
# 53      M5S  43.662696 -79.400049
# 54      M5K  43.647177 -79.381576
# 55      M3C  43.725900 -79.340923
# 56      M5M  43.733283 -79.419750
# 57      M6K  43.636847 -79.428191
# 58      M1L  43.711112 -79.284577
# 59      M9A  43.667856 -79.532242
# 60      M8Y  43.636258 -79.498509
# 61      M4T  43.689574 -79.383160
# 62      M4C  43.695344 -79.318389
# 63      M9R  43.688905 -79.554724
# 64      M5J  43.640816 -79.381752
# 65      M4J  43.685347 -79.338106
# 66      M9M  43.724766 -79.532242
# 67      M1B  43.806686 -79.194353
# 68      M5X  43.648429 -79.382280
# 69      M4Y  43.665860 -79.383160
# 70      M3L  43.739015 -79.506944
# 71      M6H  43.669005 -79.442259
# 72      M2L  43.757490 -79.374714
# 73      M5R  43.672710 -79.405678
# 74      M4X  43.667967 -79.367675
# 75      M4V  43.686412 -79.400049
# 76      M4L  43.668999 -79.315572
#
# [77 rows x 5 columns]

# %%
final_df.to_csv('final_dataset')
